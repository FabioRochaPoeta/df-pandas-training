# %%
### Trate todos os valores nulos (mean, median, mode) pq?
### Exiba os carros acima da média de preço
### Crie os seguintes filtros: conversiveis, volkswagen, 4 cilindros, tamanho do motor > 120
### Explore o dataframe e traga dúvidas (loc, iloc, rename, drop, dropna, fillna, filtros)

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_cars=pd.read_csv('cars_tratado.csv')

# %%
df_cars.columns
# Out:
# Index(['Unnamed: 0', 'index', 'symboling', 'normalized-losses', 'make',
#        'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels',
#        'engine-location', 'wheel-base', 'length', 'width', 'height',
#        'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size',
#        'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
# transformando em nulos os '?'

df_cars.replace('?', np.NaN, inplace=True)

# %%
df_cars
# Out:
#      Unnamed: 0  index  symboling  normalized-losses         make fuel-type  \
# 0             0      0          3                162  alfa-romero       gas
# 1             1      1          3                162  alfa-romero       gas
# 2             2      2          1                144  alfa-romero       gas
# 3             3      3          2                164         audi       gas
# 4             4      4          2                164         audi       gas
# ..          ...    ...        ...                ...          ...       ...
# 196         196    200         -1                 95        volvo       gas
# 197         197    201         -1                 95        volvo       gas
# 198         198    202         -1                 95        volvo       gas
# 199         199    203         -1                 95        volvo    diesel
# 200         200    204         -1                 95        volvo       gas
#
# ...

# %%
# checando tipo de price

df_cars.dtypes
# Out:
# Unnamed: 0             int64
# index                  int64
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors           int64
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders       int64
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# transformando type de price (object = string) em float (apenas float aceita Null) 
# e de todas as colunas que tem null, menos número de portas, que é por extenso e não adiantaria

p = 'price'
s = 'stroke'
b = 'bore'
pr = 'peak-rpm'
h = 'horsepower'

df_cars[p] = df_cars[p].astype(float)
df_cars[s] = df_cars[s].astype(float)
df_cars[b] = df_cars[b].astype(float)
df_cars[pr] = df_cars[pr].astype(float)
df_cars[h] = df_cars[h].astype(float)

# %%
# vendo onde tem nulo e a soma dos nulos em toda a tabela

df_cars.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0           0
# index                0
# highway-mpg          0
# city-mpg             0
# peak-rpm             0
# horsepower           0
# compression-ratio    0
# stroke               0
# bore                 0
# fuel-system          0
# engine-size          0
# num-of-cylinders     0
# engine-type          0
# curb-weight          0
# height               0
# width                0
# length               0
# wheel-base           0
# engine-location      0
# drive-wheels         0
# body-style           0
# num-of-doors         0
# aspiration           0
# fuel-type            0
# make                 0
# normalized-losses    0
# symboling            0
# price                0
# dtype: int64

# %%
# tratando os nulos do price, substituindo pela média (mean) da marca (make)
# primeiro calculando a média de cada marca:

df_cars.groupby('make')['price'].mean()
# Out:
# make
# alfa-romero      15498.333333
# audi             17859.166667
# bmw              26118.750000
# chevrolet         6007.000000
# dodge             7875.444444
# honda             8184.692308
# isuzu             8916.500000
# jaguar           34600.000000
# mazda            10652.882353
# mercedes-benz    33647.000000
# mercury          16503.000000
# mitsubishi        9239.769231
# nissan           10415.666667
# peugot           15489.090909
# plymouth          7963.428571
# porsche          31400.500000
# renault           9595.000000
# saab             15223.333333
# subaru            8541.250000
# toyota            9885.812500
# volkswagen       10077.500000
# volvo            18063.181818
# Name: price, dtype: float64

# %%
# listando carros com preço nulo

df_cars[df_cars['price'].isnull()]['make'].unique()
# Out:
# array([], dtype=object)

# %%
## fazendo o for para as 4 colunas que tem nulos e já são float (para substituir o nulo pelas médias) - não consegui

for make in df_cars[df_cars['price'].isnull()]['make'].unique():
    df_cars('make')['price'] = df_cars('make')['price'].mean()

# %%
# tentando sem for, já que não roda, apenas para o preço inicialmente (essa média não considera as marcas)

avg_price = df_cars['price'].astype(float).mean()
df_cars['price'].replace(np.NaN, avg_price, inplace=True)

# %%
# vendo qual foi a média de preço

avg_price
# Out:
# 13207.129353233831

# %%
# checando se saíram os nulos do preço - sim, foi de 4 para 0

df_cars.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0           0
# index                0
# highway-mpg          0
# city-mpg             0
# peak-rpm             0
# horsepower           0
# compression-ratio    0
# stroke               0
# bore                 0
# fuel-system          0
# engine-size          0
# num-of-cylinders     0
# engine-type          0
# curb-weight          0
# height               0
# width                0
# length               0
# wheel-base           0
# engine-location      0
# drive-wheels         0
# body-style           0
# num-of-doors         0
# aspiration           0
# fuel-type            0
# make                 0
# normalized-losses    0
# symboling            0
# price                0
# dtype: int64

# %%
### Exiba os carros acima da média de preço 

df_cars[(df_cars['price'] >= avg_price)]
# Out:
#      Unnamed: 0  index  symboling  normalized-losses         make fuel-type  \
# 0             0      0          3                162  alfa-romero       gas
# 1             1      1          3                162  alfa-romero       gas
# 2             2      2          1                144  alfa-romero       gas
# 3             3      3          2                164         audi       gas
# 4             4      4          2                164         audi       gas
# ..          ...    ...        ...                ...          ...       ...
# 196         196    200         -1                 95        volvo       gas
# 197         197    201         -1                 95        volvo       gas
# 198         198    202         -1                 95        volvo       gas
# 199         199    203         -1                 95        volvo    diesel
# 200         200    204         -1                 95        volvo       gas
#
# ...

# %%
# para exibir todas as colunas e linhas (são 78 linhas, cada uma com um carro):

pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

df_cars[(df_cars['price'] >= avg_price)]
# Out:
#      Unnamed: 0  index  symboling  normalized-losses           make fuel-type  \
# 0             0      0          3                162    alfa-romero       gas
# 1             1      1          3                162    alfa-romero       gas
# 2             2      2          1                144    alfa-romero       gas
# 3             3      3          2                164           audi       gas
# 4             4      4          2                164           audi       gas
# 5             5      5          2                157           audi       gas
# 6             6      6          1                158           audi       gas
# 7             7      7          1                137           audi       gas
# 8             8      8          1                158           audi       gas
# 9             9     10          2                192            bmw       gas
# 10           10     11          0                192            bmw       gas
# ...

# %%
### Crie os seguintes filtros: conversiveis, volkswagen, 4 cilindros, tamanho do motor > 120 - ? 
# (Mudei para tamanho do motor > 50 senão não tem nenhum carro com todas essas características ao mesmo tempo)

df_cars[(df_cars['body-style'] == 'convertible') & (df_cars['make'] == 'volkswagen') & 
(df_cars['num-of-cylinders'] == 'four') & (df_cars['engine-size'] >= 50) ]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, index, symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []

# %%
### Explore o dataframe e traga dúvidas (loc, iloc, rename, drop, dropna, fillna, filtros)

# treinando rename - e voltando pra visualização condensada - renomeei a coluna make
# Rename columns or index labels.
# DataFrame.rename(mapper=None, *, index=None, columns=None, axis=None, copy=None, inplace=False, level=None, errors='ignore')[source]

df_cars.rename(columns={"make": "marca"}, inplace=True)

pd.set_option("display.max_columns", 15)
pd.set_option("display.max_rows", 5)

df_cars
# Out:
#      Unnamed: 0  index  symboling  normalized-losses        marca fuel-type  \
# 0             0      0          3                162  alfa-romero       gas
# 1             1      1          3                162  alfa-romero       gas
# ..          ...    ...        ...                ...          ...       ...
# 199         199    203         -1                 95        volvo    diesel
# 200         200    204         -1                 95        volvo       gas
#
#     aspiration  ...  stroke compression-ratio horsepower peak-rpm  city-mpg  \
# 0          std  ...    2.68               9.0      111.0   5000.0        21
# 1          std  ...    2.68               9.0      111.0   5000.0        21
# ..         ...  ...     ...               ...        ...      ...       ...
# 199      turbo  ...    3.40              23.0      106.0   4800.0        26
# 200      turbo  ...    3.15               9.5      114.0   5400.0        19
#
#      highway-mpg    price
# ...

# %%
# treinando dropna - apagando linhas onde há NA - pq nao apagou linha 0 e 1?
# Remove missing values.
# DataFrame.dropna(*, axis=0, how=_NoDefault.no_default, thresh=_NoDefault.no_default, subset=None, inplace=False, ignore_index=False)

df_cars.dropna(inplace=True)
df_cars
# Out:
#      Unnamed: 0  index  symboling  normalized-losses        marca fuel-type  \
# 0             0      0          3                162  alfa-romero       gas
# 1             1      1          3                162  alfa-romero       gas
# ..          ...    ...        ...                ...          ...       ...
# 199         199    203         -1                 95        volvo    diesel
# 200         200    204         -1                 95        volvo       gas
#
#     aspiration  ...  stroke compression-ratio horsepower peak-rpm  city-mpg  \
# 0          std  ...    2.68               9.0      111.0   5000.0        21
# 1          std  ...    2.68               9.0      111.0   5000.0        21
# ..         ...  ...     ...               ...        ...      ...       ...
# 199      turbo  ...    3.40              23.0      106.0   4800.0        26
# 200      turbo  ...    3.15               9.5      114.0   5400.0        19
#
#      highway-mpg    price
# ...

# %%
# treinando drop - apaguei a coluna Marca
# Drop specified labels from rows or columns.
# DataFrame.drop(labels=None, *, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')[source]

df_cars.drop(columns=['marca'], inplace=True)
df_cars
# Out:
#      Unnamed: 0  index  symboling  normalized-losses fuel-type aspiration  \
# 0             0      0          3                162       gas        std
# 1             1      1          3                162       gas        std
# ..          ...    ...        ...                ...       ...        ...
# 199         199    203         -1                 95    diesel      turbo
# 200         200    204         -1                 95       gas      turbo
#
#      num-of-doors  ... stroke compression-ratio horsepower  peak-rpm  \
# 0               2  ...   2.68               9.0      111.0    5000.0
# 1               2  ...   2.68               9.0      111.0    5000.0
# ..            ...  ...    ...               ...        ...       ...
# 199             4  ...   3.40              23.0      106.0    4800.0
# 200             4  ...   3.15               9.5      114.0    5400.0
#
#      city-mpg  highway-mpg    price
# 0          21           27  13495.0
# ...

# %%
# treinando fillna - substituindo todos os NaN por 'teste'
# Fill NA/NaN values using the specified method.
# DataFrame.fillna(value=None, *, method=None, axis=None, inplace=False, limit=None, downcast=None)[source]

df_cars.fillna('Teste', inplace=True)
df_cars
# Out:
#      Unnamed: 0  index  symboling  normalized-losses fuel-type aspiration  \
# 0             0      0          3                162       gas        std
# 1             1      1          3                162       gas        std
# ..          ...    ...        ...                ...       ...        ...
# 199         199    203         -1                 95    diesel      turbo
# 200         200    204         -1                 95       gas      turbo
#
#      num-of-doors  ... stroke compression-ratio horsepower  peak-rpm  \
# 0               2  ...   2.68               9.0      111.0    5000.0
# 1               2  ...   2.68               9.0      111.0    5000.0
# ..            ...  ...    ...               ...        ...       ...
# 199             4  ...   3.40              23.0      106.0    4800.0
# 200             4  ...   3.15               9.5      114.0    5400.0
#
#      city-mpg  highway-mpg    price
# 0          21           27  13495.0
# ...

# %%
# treinando concat
# Concatenate pandas objects along a particular axis.
# pandas.concat(objs, *, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=None)
 
new_row = pd.Series({'a': 3, 'b': 4})
pd.concat([df_cars, new_row.to_frame().T], ignore_index=True)
# Out:
#      Unnamed: 0  index  symboling  normalized-losses fuel-type aspiration  \
# 0           0.0    0.0        3.0              162.0       gas        std
# 1           1.0    1.0        3.0              162.0       gas        std
# ..          ...    ...        ...                ...       ...        ...
# 200       200.0  204.0       -1.0               95.0       gas      turbo
# 201         NaN    NaN        NaN                NaN       NaN        NaN
#
#      num-of-doors  ... horsepower peak-rpm city-mpg  highway-mpg    price  \
# 0             2.0  ...      111.0   5000.0     21.0         27.0  13495.0
# 1             2.0  ...      111.0   5000.0     21.0         27.0  16500.0
# ..            ...  ...        ...      ...      ...          ...      ...
# 200           4.0  ...      114.0   5400.0     19.0         25.0  22625.0
# 201           NaN  ...        NaN      NaN      NaN          NaN      NaN
#
#        a    b
# 0    NaN  NaN
# 1    NaN  NaN
# ..   ...  ...
# ...

# %%
# treinando crosstab
# Compute a simple cross tabulation of two (or more) factors. - Get insights
# pandas.crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name='All', dropna=True, normalize=False)

pd.crosstab(df_cars['make'], df_cars['symboling'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
# treinando get_dummies
# Convert categorical variable into dummy/indicator variables. (0/1)
# pandas.get_dummies(data, prefix=None, prefix_sep='_', dummy_na=False, columns=None, sparse=False, drop_first=False, dtype=None)

pd.get_dummies(df_cars)
# Out:
#      Unnamed: 0  symboling  wheel-base  length  width  height  curb-weight  \
# 0             0          3        88.6   168.8   64.1    48.8         2548
# 1             1          3        88.6   168.8   64.1    48.8         2548
# 2             2          1        94.5   171.2   65.5    52.4         2823
# 3             3          2        99.8   176.6   66.2    54.3         2337
# 4             4          2        99.4   176.6   66.4    54.3         2824
# ..          ...        ...         ...     ...    ...     ...          ...
# 200         200         -1       109.1   188.8   68.9    55.5         2952
# 201         201         -1       109.1   188.8   68.8    55.5         3049
# 202         202         -1       109.1   188.8   68.9    55.5         3012
# 203         203         -1       109.1   188.8   68.9    55.5         3217
# 204         204         -1       109.1   188.8   68.9    55.5         3062
#
#      engine-size  bore  stroke  ...  num-of-cylinders_twelve  \
# ...

# %%
# pd.cut
# Bin values into discrete intervals. - classes
# pandas.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise', ordered=True)

classes_bins = [0, 10000, 20000, 30000, 40000, 50000]
labels = ['E', 'D', 'C', 'B', 'A']

pd.cut(df_cars['price'], bins=classes_bins, labels=labels)
# Out:
# 0      D
# 1      D
# 2      D
# 3      D
# 4      D
#       ..
# 200    D
# 201    D
# 202    C
# 203    C
# 204    C
# Name: price, Length: 205, dtype: category
# Categories (5, object): ['E' < 'D' < 'C' < 'B' < 'A']

# %%
# np.linspace (numpy) - outra forma de fazer o de cima
# Return evenly spaced numbers over a specified interval.
# numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)

np.linspace(0, 50000, num=5)
# Out:
# array([    0., 12500., 25000., 37500., 50000.])

# %%
# matplotlib

x = df_cars['price']
y = df_cars['symboling']

fig, ax = plt.subplots()
ax.plot(x, y)
plt.title("Buscando Relação")
plt.xlabel("Preço R$")
plt.ylabel("Valor de Risco")
plt.show()

# %%
# matplotlib

plt.scatter(x, y);
plt.title("Buscando Relação")
plt.xlabel("Preço R$")
plt.ylabel("Valor de Risco")
plt.show()

# %%
# preço e risco não tem uma relação clara

# %%
## subplots - acho que do exemplo em aula os títulos gos gráficos estão trocados:

fig, axes = plt.subplots(1, 2, figsize=(12, 4))


fig.suptitle("Titulo Geral")
axes[0].set_title("Frequencia Preço")
axes[1].set_title("Preço x Horsepower")


df_cars['price'].plot(kind='hist', ax=axes[1])

df_cars.plot(
    kind='scatter', 
    x='price', 
    y='horsepower',
    s=80,
    alpha=0.5,
    color='green',
    ax=axes[0])

plt.show()

# %%
## fill_between não funcionou 

fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(8, 15))

fig.suptitle("Achando uma relação")
axes[0].set_title("Preço x Horsepower")
axes[1].set_title("Frequência de Preço")
axes[2].set_title("Frequência de Horsepower")

df_cars.plot(
    kind='scatter', 
    x='price', 
    y='horsepower',
    s=80,
    alpha=0.5,
    color='blue',
    ax=axes[0])

# mpl.pyplot.fill_between('0','50000', color='black', ax=axes[0])

df_cars['price'].plot(kind='hist', color='red', ax=axes[1])

df_cars['horsepower'].plot(kind='hist', color='green', ax=axes[2])

plt.show()

# %%
## tentando mudar pro tipo de gráfico pcolormesh que precisa de 3 valores, reclamou rs
# e fez gráfico em branco
# ValueError: x and y arguments to pcolormesh cannot have non-finite values or be of type numpy.ma.core.MaskedArray with masked values

z = df_cars['bore']

plt.pcolormesh(x, y, z);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 z = df_cars['bore']
# ----> 3 plt.pcolormesh(x, y, z);
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2773, in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2768 @_copy_docstring_and_deprecators(Axes.pcolormesh)
#    2769 def pcolormesh(
#    2770         *args, alpha=None, norm=None, cmap=None, vmin=None,
#    2771         vmax=None, shading=None, antialiased=False, data=None,
#    2772         **kwargs):
# -> 2773     __ret = gca().pcolormesh(
#    2774         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2775         vmax=vmax, shading=shading, antialiased=antialiased,
# ...

# %%
## contour

plt.contour(x, y, z);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 plt.contour(x, y, z);
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2527, in contour(data, *args, **kwargs)
#    2525 @_copy_docstring_and_deprecators(Axes.contour)
#    2526 def contour(*args, data=None, **kwargs):
# -> 2527     __ret = gca().contour(
#    2528         *args, **({"data": data} if data is not None else {}),
#    2529         **kwargs)
#    2530     if __ret._A is not None: sci(__ret)  # noqa
#    2531     return __ret
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
# ...
